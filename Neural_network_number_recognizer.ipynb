# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolwesley/neural-network-scratch-/blob/main/Neural_network_number_recognizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
