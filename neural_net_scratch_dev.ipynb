# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolwesley/neural-network-scratch-/blob/main/neural_net_scratch_dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# The training data: each pair is (input, correct_answer).
# The answer is always 2x the input — but we never tell the network that.
data = [
    (1.0, 2.0),
    (2.0, 4.0),
    (3.0, 6.0),
    (4.0, 8.0),
]

# Start the weight at a RANDOM guess (never 0).
weight = random.uniform(-1.0, 1.0)
print(f"Starting weight (random guess): {weight:.4f}")
print("The network must discover that this should become 2.0\n")

# How big a step we take downhill each time. THIS is the knob to play with.
learning_rate = 0.01

# How many times we loop over all the data.
epochs = 100

for epoch in range(epochs):
    total_error_squared = 0.0

    for x, correct in data:
        prediction = x * weight              # forward pass
        error = prediction - correct         # how wrong, with sign
        total_error_squared += error ** 2    # squared error (for reporting)
        slope = 2 * error * x                # the gradient
        weight = weight - learning_rate * slope   # step downhill

    if epoch % 10 == 0:
        print(f"Epoch {epoch:3d} | weight = {weight:.4f} | total error = {total_error_squared:.4f}")

print(f"\nFinal weight: {weight:.4f}  (target was 2.0)")
print(f"Test: input 10 -> prediction {10 * weight:.4f}  (should be ~20)")
# Out:
# Starting weight (random guess): 0.2828
# The network must discover that this should become 2.0
#
# Epoch   0 | weight = 1.1367 | total error = 61.6364
# Epoch  10 | weight = 1.9991 | total error = 0.0001
# Epoch  20 | weight = 2.0000 | total error = 0.0000
# Epoch  30 | weight = 2.0000 | total error = 0.0000
# Epoch  40 | weight = 2.0000 | total error = 0.0000
# Epoch  50 | weight = 2.0000 | total error = 0.0000
# Epoch  60 | weight = 2.0000 | total error = 0.0000
# Epoch  70 | weight = 2.0000 | total error = 0.0000
# Epoch  80 | weight = 2.0000 | total error = 0.0000
# Epoch  90 | weight = 2.0000 | total error = 0.0000
#
# Final weight: 2.0000  (target was 2.0)
# Test: input 10 -> prediction 20.0000  (should be ~20)

# %% [markdown]
# A sigmoid function that takes real-value input and turns it into an S-shaped graph with the out of that graph being between 0-1. Neural networks need it to introduce nonlinearity. Thus allowing it to model complex data and convert the raw output into probabilities for binary classification. Unlike linear activation functions, sigmoid allows neural networks to learn non-linear patterns in data, which is necessary for complex, real-world problems.
